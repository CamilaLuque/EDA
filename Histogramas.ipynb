# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df2 = pd.read_csv('/distancias_10.txt', sep='/n', header=None)
dim2 = df2.T.squeeze()
dim2.plot.hist(grid=True, bins=20, rwidth=0.9, color='#607c8e')
plt.title('Histograma de las distancias entre puntos con dimensión 10')
plt.xlabel('Distancia')
plt.ylabel('Frecuencia')
plt.grid(axis='y', alpha=0.75)
plt.xlim(0,2)
plt.show()
# Out:
# <ipython-input-4-0dc7241dff37>:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df2 = pd.read_csv('/distancias_10.txt', sep='/n', header=None)

# %%
df3 = pd.read_csv('/distancias_50.txt', sep='/n', header=None)
dim3 = df3.T.squeeze()
dim3.plot.hist(grid=True, bins=20, rwidth=0.9, color='#607c8e')
plt.title('Histograma de las distancias entre puntos con dimensión 50')
plt.xlabel('Distancia')
plt.ylabel('Frecuencia')
plt.grid(axis='y', alpha=0.75)
plt.xlim(0,3.8)
plt.show()
# Out:
# <ipython-input-5-1df55586de9b>:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df3 = pd.read_csv('/distancias_50.txt', sep='/n', header=None)

# %%
df4 = pd.read_csv('/distancias_100.txt', sep='/n', header=None)
dim4 = df4.T.squeeze()
dim4.plot.hist(grid=True, bins=20, rwidth=0.9, color='#607c8e')
plt.title('Histograma de las distancias entre puntos con dimensión 100')
plt.xlabel('Distancia')
plt.ylabel('Frecuencia')
plt.grid(axis='y', alpha=0.75)
plt.xlim(0,5)
plt.show()
# Out:
# <ipython-input-6-0a64e5660c89>:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df4 = pd.read_csv('/distancias_100.txt', sep='/n', header=None)

# %%
df5 = pd.read_csv('/distancias_500.txt', sep='/n', header=None)
dim5 = df5.T.squeeze()
dim5.plot.hist(grid=True, bins=20, rwidth=0.9, color='#607c8e')
plt.title('Histograma de las distancias entre puntos con dimensión 500')
plt.xlabel('Distancia')
plt.ylabel('Frecuencia')
plt.grid(axis='y', alpha=0.75)
plt.xlim(0,10)
plt.show()
# Out:
# <ipython-input-7-8a6ac3a2810f>:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df5 = pd.read_csv('/distancias_500.txt', sep='/n', header=None)

# %%
df6 = pd.read_csv('/distancias_1000.txt', sep='/n', header=None)
dim6 = df6.T.squeeze()
dim6.plot.hist(grid=True, bins=20, rwidth=0.9, color='#607c8e')
plt.title('Histograma de las distancias entre puntos con dimensión 1000')
plt.xlabel('Distancia')
plt.ylabel('Frecuencia')
plt.grid(axis='y', alpha=0.75)
plt.xlim(0,14)
plt.show()
# Out:
# <ipython-input-8-b058686a19f0>:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df6 = pd.read_csv('/distancias_1000.txt', sep='/n', header=None)

# %%
df7 = pd.read_csv('/distancias_2000.txt', sep='/n', header=None)
dim7 = df7.T.squeeze()
dim7.plot.hist(grid=True, bins=20, rwidth=0.9, color='#607c8e')
plt.title('Histograma de las distancias entre puntos con dimensión 2000')
plt.xlabel('Distancia')
plt.ylabel('Frecuencia')
plt.grid(axis='y', alpha=0.75)
plt.xlim(0,20)
plt.show()
# Out:
# <ipython-input-9-7bcf86617a3a>:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df7 = pd.read_csv('/distancias_2000.txt', sep='/n', header=None)

# %%
df8 = pd.read_csv('/distancias_5000.txt', sep='/n', header=None)
dim8 = df8.T.squeeze()
dim8.plot.hist(grid=True, bins=20, rwidth=0.9, color='#607c8e')
plt.title('Histograma de las distancias entre puntos con dimensión 5000')
plt.xlabel('Distancia')
plt.ylabel('Frecuencia')
plt.grid(axis='y', alpha=0.75)
plt.xlim(0,30)
plt.show()
# Out:
# <ipython-input-10-9dcaf9b122cc>:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df8 = pd.read_csv('/distancias_5000.txt', sep='/n', header=None)
